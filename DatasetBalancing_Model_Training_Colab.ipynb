# %% [markdown]
# # Dataset Balancing

# %% [markdown]
# The [PlantVillage-Dataset](https://github.com/spMohanty/PlantVillage-Dataset/blob/master/README.md), is a dataset of plant leaf images  categorized per species and per health conditions. The dataset containes 38 classes, but the number of elements per class can vary significantly between them.
#
# Although the dataset includes 38 classes, the number of samples per class varies significantly, making the dataset imbalanced.
#
# This notebook aims to balance the classes through different methods: by applying a class-specific data augmentation and downsampling or by applaying oversampling and downsampling, and then to proceed with the training of the model with the augmented dataset.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Install required libraries
# %pip install tensorflow_datasets
#%pip install collections
# Out:
# Requirement already satisfied: tensorflow_datasets in /usr/local/lib/python3.12/dist-packages (4.9.9)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.12/dist-packages (from tensorflow_datasets) (1.4.0)
# Requirement already satisfied: array_record>=0.5.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow_datasets) (0.8.1)
# Requirement already satisfied: dm-tree in /usr/local/lib/python3.12/dist-packages (from tensorflow_datasets) (0.1.9)
# Requirement already satisfied: etils>=1.9.1 in /usr/local/lib/python3.12/dist-packages (from etils[edc,enp,epath,epy,etree]>=1.9.1; python_version >= "3.11"->tensorflow_datasets) (1.13.0)
# Requirement already satisfied: immutabledict in /usr/local/lib/python3.12/dist-packages (from tensorflow_datasets) (4.2.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from tensorflow_datasets) (2.0.2)
# Requirement already satisfied: promise in /usr/local/lib/python3.12/dist-packages (from tensorflow_datasets) (2.3)
# Requirement already satisfied: protobuf>=3.20 in /usr/local/lib/python3.12/dist-packages (from tensorflow_datasets) (5.29.5)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from tensorflow_datasets) (5.9.5)
# Requirement already satisfied: pyarrow in /usr/local/lib/python3.12/dist-packages (from tensorflow_datasets) (18.1.0)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow_datasets) (2.32.4)
# Requirement already satisfied: simple_parsing in /usr/local/lib/python3.12/dist-packages (from tensorflow_datasets) (0.1.7)
# Requirement already satisfied: tensorflow-metadata in /usr/local/lib/python3.12/dist-packages (from tensorflow_datasets) (1.17.2)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.12/dist-packages (from tensorflow_datasets) (3.1.0)
# Requirement already satisfied: toml in /usr/local/lib/python3.12/dist-packages (from tensorflow_datasets) (0.10.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from tensorflow_datasets) (4.67.1)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.12/dist-packages (from tensorflow_datasets) (1.17.3)
# Requirement already satisfied: einops in /usr/local/lib/python3.12/dist-packages (from etils[edc,enp,epath,epy,etree]>=1.9.1; python_version >= "3.11"->tensorflow_datasets) (0.8.1)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from etils[edc,enp,epath,epy,etree]>=1.9.1; python_version >= "3.11"->tensorflow_datasets) (2025.3.0)
# Requirement already satisfied: importlib_resources in /usr/local/lib/python3.12/dist-packages (from etils[edc,enp,epath,epy,etree]>=1.9.1; python_version >= "3.11"->tensorflow_datasets) (6.5.2)
# Requirement already satisfied: typing_extensions in /usr/local/lib/python3.12/dist-packages (from etils[edc,enp,epath,epy,etree]>=1.9.1; python_version >= "3.11"->tensorflow_datasets) (4.15.0)
# Requirement already satisfied: zipp in /usr/local/lib/python3.12/dist-packages (from etils[edc,enp,epath,epy,etree]>=1.9.1; python_version >= "3.11"->tensorflow_datasets) (3.23.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->tensorflow_datasets) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->tensorflow_datasets) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->tensorflow_datasets) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->tensorflow_datasets) (2025.8.3)
# Requirement already satisfied: attrs>=18.2.0 in /usr/local/lib/python3.12/dist-packages (from dm-tree->tensorflow_datasets) (25.3.0)
# Requirement already satisfied: six in /usr/local/lib/python3.12/dist-packages (from promise->tensorflow_datasets) (1.17.0)
# Requirement already satisfied: docstring-parser<1.0,>=0.15 in /usr/local/lib/python3.12/dist-packages (from simple_parsing->tensorflow_datasets) (0.17.0)
# Requirement already satisfied: googleapis-common-protos<2,>=1.56.4 in /usr/local/lib/python3.12/dist-packages (from tensorflow-metadata->tensorflow_datasets) (1.70.0)

# %%
# Import all necessary libraries and functions
from collections import Counter
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import tensorflow_datasets as tfds
import os
import pandas as pd
import random
from tqdm.notebook import tqdm

# %%
# Seed setting for reproducibility
random.seed(42)
np.random.seed(42)
tf.random.set_seed(42)
tf.keras.utils.set_random_seed(42)

# %%
# Load the PlantVillage dataset from the tensorflow_datasets library
(ds_train, ds_val, ds_test), ds_info = tfds.load(
    'plant_village',
    split=['train[:80%]', 'train[80%:90%]', 'train[90%:]'],
    shuffle_files=True,
    as_supervised=True,  # returns (image, label) pairs
    with_info=True    #returns metadata regarding the dataset
)

# Count number of samples in each subset
train_count = sum(1 for _ in ds_train)
val_count = sum(1 for _ in ds_val)
test_count = sum(1 for _ in ds_test)
dataset_count = train_count + val_count + test_count

print(f"The Plantvillage dataset contains: {dataset_count} samples")
print("Dataset Splitting: 80/10/10 Train-Validation-Test Ratio")
print(f"Training set: {train_count} samples")
print(f"Validation set: {val_count} samples")
print(f"Test set: {test_count} samples")
# Out:
# WARNING:absl:Variant folder /root/tensorflow_datasets/plant_village/1.0.2 has no dataset_info.json
# Downloading and preparing dataset Unknown size (download: Unknown size, generated: Unknown size, total: Unknown size) to /root/tensorflow_datasets/plant_village/1.0.2...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# Extraction completed...: 0 file [00:00, ? file/s]
# Generating splits...:   0%|          | 0/1 [00:00<?, ? splits/s]
# Generating train examples...: 0 examples [00:00, ? examples/s]
# Shuffling /root/tensorflow_datasets/plant_village/incomplete.HBRPOI_1.0.2/plant_village-train.tfrecord*...:   …
# Dataset plant_village downloaded and prepared to /root/tensorflow_datasets/plant_village/1.0.2. Subsequent calls will reuse this data.
# The Plantvillage dataset contains: 54303 samples
# Dataset Splitting: 80/10/10 Train-Validation-Test Ratio
# Training set: 43442 samples
# Validation set: 5431 samples
# Test set: 5430 samples

# %% [markdown]
# ## Training dataset balancing: data augmentation and over/downsampling

# %% [markdown]
# Data augmentation is a dataset balancing process that can impact the response of a model during the training phase. This is due to the fact that the resulting augmented images vary depending on the specific transformations applied during the augmentation.
# This notebooks aim is to evaluate the impact of different transformations on model performance by applying three different data augmentation pipelines to the training dataset:
# - Geometric data augmentation: uses transformations that translate, rotate and zooming in or out of the original image. These mimic the various spatial positions in which the same leaf might appear.
#
# - Color data augmentation: uses transformations that alters the value of the pixel by randomly adjusting brightness, saturation and contrast of the original image. This mimics the variability in lighting conditions under which the same leaf may be observed.
#
# - Combined data augmentation: uses the combination of all the previous transformation. By bringing together the two previous groups of transformations, this pipeline is expected to best simulate the randomness and variability encountered in real-world scenarios.

# %% [markdown]
# Original training dataset information:

# %%
# Extract only labels (not images) for counting
labels_list = []
for _, label in ds_train:      # Iterate over the dataset, ignoring the image (_) and extracting the label
    labels_list.append(label.numpy())

# Convert to pandas Series for fast operations
labels_series = pd.Series(labels_list)

number_of_classes = ds_info.features['label'].num_classes
print(f"Number of classes: {number_of_classes}")
class_names = ds_info.features['label'].names

# Count using pandas (fast) but memory-efficient
class_counts = labels_series.value_counts().sort_index()

# Count original class samples (before augmentation)
original_counts = labels_series.value_counts().sort_index()

# Show example from the dataset
tfds.show_examples(ds_train, ds_info)

plt.figure(figsize=(12,6))
plt.bar(class_names, original_counts)
plt.title("Class distribution before augmentation")
plt.xlabel("Class")
plt.ylabel("Number of images")
plt.xticks(rotation=90)
plt.show()

# Print the counts with class names
print("Number of images per class:")
for idx, count in class_counts.items():
    print(f"{class_names[idx]}: {count} images")
# Out:
# Number of classes: 38
# Number of images per class:
# Apple___Apple_scab: 501 images
# Apple___Black_rot: 467 images
# Apple___Cedar_apple_rust: 221 images
# Apple___healthy: 1306 images
# Blueberry___healthy: 1210 images
# Cherry___healthy: 659 images
# Cherry___Powdery_mildew: 851 images
# Corn___Cercospora_leaf_spot Gray_leaf_spot: 405 images
# Corn___Common_rust: 953 images
# Corn___healthy: 939 images
# Corn___Northern_Leaf_Blight: 788 images
# Grape___Black_rot: 956 images
# Grape___Esca_(Black_Measles): 1111 images
# Grape___healthy: 349 images
# Grape___Leaf_blight_(Isariopsis_Leaf_Spot): 881 images
# Orange___Haunglongbing_(Citrus_greening): 4399 images
# Peach___Bacterial_spot: 1838 images
# Peach___healthy: 292 images
# Pepper,_bell___Bacterial_spot: 800 images
# Pepper,_bell___healthy: 1173 images
# Potato___Early_blight: 792 images
# Potato___healthy: 122 images
# Potato___Late_blight: 801 images
# Raspberry___healthy: 302 images
# Soybean___healthy: 4043 images
# Squash___Powdery_mildew: 1466 images
# Strawberry___healthy: 353 images
# Strawberry___Leaf_scorch: 923 images
# Tomato___Bacterial_spot: 1732 images
# Tomato___Early_blight: 807 images
# Tomato___healthy: 1261 images
# Tomato___Late_blight: 1535 images
# Tomato___Leaf_Mold: 758 images
# Tomato___Septoria_leaf_spot: 1409 images
# Tomato___Spider_mites Two-spotted_spider_mite: 1360 images
# Tomato___Target_Spot: 1124 images
# Tomato___Tomato_mosaic_virus: 303 images
# Tomato___Tomato_Yellow_Leaf_Curl_Virus: 4252 images

# %%
# Useful constants
IMG_SIZE = (128, 128)
BATCH_SIZE = 64
N_EPOCHS = 30
NUM_CLASSES = ds_info.features['label'].num_classes
DROP_RATE = 0.3
L2_REGULARIZATION = 0.005

# %% [markdown]
# Target sample size and data augmentation pipelines definition:

# %%
# Preprocess for non-augmented datasets
def preprocess(image, label, dataset_info, image_size=(128, 128)):
    image = tf.image.resize(image, image_size)
    image = tf.cast(image, tf.float32) / 255.0
    return image, tf.one_hot(label, dataset_info.features['label'].num_classes)

# Geometric augmentation
geo_augmentation = tf.keras.Sequential([
    tf.keras.layers.RandomZoom(0.7),
    # tf.keras.layers.RandomTranslation(0.1, 0.1),
    # tf.keras.layers.RandomRotation(1),
])

# Preprocess for geometrically augmented datasets
def preprocess_geo_aug(image, label):
    image = tf.image.resize(image, IMG_SIZE)
    image = tf.cast(image, tf.float32) / 255.0
    return image, tf.one_hot(label, ds_info.features['label'].num_classes)

# Color augmentation
color_augmentation = tf.keras.Sequential([
    tf.keras.layers.RandomBrightness(0.5),  # Brightness change
    tf.keras.layers.RandomContrast(0.5),    # Contrast variation
    # tf.keras.layers.RandomSaturation(0.4),  # No color intensity variation bc it's not natural (at least in the prelim.)
    # tf.keras.layers.RandomHue(1)       # (optional) Hue variation
])

# Preprocess for color augmented datasets
def preprocess_color_aug(image, label):
    image = tf.image.resize(image, IMG_SIZE)
    image = tf.clip_by_value(aug_image, 0.0, 255.0)
    image = tf.cast(aug_image, tf.uint8)
    image = tf.cast(image, tf.float32) / 255.0
    return image, tf.one_hot(label, ds_info.features['label'].num_classes)

# Combining the two types of augmentation
combined_data_augmentation = tf.keras.Sequential([
    # Geometric augmentations
    # tf.keras.layers.RandomRotation(0.1),
    tf.keras.layers.RandomZoom(0.7),
    #tf.keras.layers.RandomTranslation(0.1, 0.1),

    # Color augmentations
    tf.keras.layers.RandomBrightness(0.5),
    tf.keras.layers.RandomContrast(0.5),
    #tf.keras.layers.Lambda(lambda x: tf.image.random_saturation(x, 0.8, 1.2)),
])

# Preprocess for geometrically and color augmented datasets
def preprocess_combined_aug(image, label):
    image = tf.image.resize(image, IMG_SIZE)
    image = tf.cast(image, tf.float32) / 255.0
    return image, label, ds_info.features['label'].num_classes

# Preprocess for color augmented datasets
def preprocess_upsampling(image, label):
    image = tf.image.resize(image, IMG_SIZE)
    image = tf.clip_by_value(aug_image, 0.0, 255.0)
    image = tf.cast(aug_image, tf.uint8)
    image = tf.cast(image, tf.float32) / 255.0
    return image, tf.one_hot(label, ds_info.features['label'].num_classes)

# %% [markdown]
# ## Augmentation

# %%
# Choose number of samples per class:
#'max': # of samples in largest class
#'mean': mean # of samples
#'t': 200 samples
#'min': # of samples in the smallest class

target_type = input("Choose the number of samples per class('max', 'mean', 't', 'min'): ").strip().lower()
if target_type not in ['max', 'mean', 't', 'min', 'p']:
    raise ValueError("Invalid choice! Please enter 'max', 'mean', 't', or 'min'.")

print(f"You chose: {target_type}")

if target_type == 'max':
  target = class_counts.max()

elif target_type == 'mean':
  target = round(class_counts.mean())

elif target_type == 't':
  target = 200

elif target_type == 'p':
  target = 20

elif target_type == 'min':
  target = class_counts.min()

samplesize = str(target)

# Choose a balancing method type:
#'comb': geometric and color augmentation
#'geo': geometric augmentation
#'color': color augmentation
#'sampl': upsampling/downsampling

augmentation_type = input("Choose augmentation type ('comb', 'geo', 'color', 'sampl'): ").strip().lower()
if augmentation_type not in ['comb', 'geo', 'color', 'sampl']:
    raise ValueError("Invalid choice! Please enter 'comb', 'geo', 'color' or 'sampl'.")

print(f"You chose: {augmentation_type}")

if augmentation_type == 'comb':
  def augment(image):
    image = combined_data_augmentation(image)
    return image
  def preprocess_aug(image, label):
    image = tf.image.resize(image, IMG_SIZE)
    image = tf.clip_by_value(image, 0.0, 255.0)
    image = tf.cast(image, tf.float32) / 255.0
    return image, label

elif augmentation_type == 'geo':
  def augment(image):
    image = geo_augmentation(image)
    return image

  def preprocess_aug(image, label):
    image = tf.image.resize(image, IMG_SIZE)
    image = tf.cast(image, tf.float32) / 255.0
    return image, label

elif augmentation_type == 'color':
  def augment(image):
    image = color_augmentation(image)
    return image

  def preprocess_aug(image, label):
    image = tf.image.resize(image, IMG_SIZE)
    image = tf.clip_by_value(image, 0.0, 255.0)
    image = tf.cast(image, tf.float32) / 255.0
    return image, label

elif augmentation_type == 'sampl':
  def augment(image):
    image = image
    return image

  def preprocess_aug(image, label):
    image = tf.image.resize(image, IMG_SIZE)
    image = tf.clip_by_value(image, 0.0, 255.0)
    image = tf.cast(image, tf.float32) / 255.0
    return image, label

# Setting output directory to Google Drive folder and creating the new classes
# output_root = 'G:/My Drive/MACHINE_LEARNING/progetto-daml'+augmentation_type+'_aug_'+samplesize
output_root = '/content/drive/MyDrive/progetto-daml/Balanced_dataset/'+ augmentation_type+'_aug_'+ samplesize
print(f'New classes path: {output_root}')
# Out:
# Choose the number of samples per class('max', 'mean', 't', 'min'): t
# You chose: t
# Choose augmentation type ('comb', 'geo', 'color', 'sampl'): sampl
# You chose: sampl
# New classes path: /content/drive/MyDrive/progetto-daml/Balanced_dataset/sampl_aug_200

# %%
# Creating new empty classes
os.makedirs(output_root, exist_ok=True)
for class_name in class_names:
    os.makedirs(os.path.join(output_root, class_name), exist_ok=True)

# Convert class_counts to dict for faster lookup
class_counts_dict = dict(class_counts)
target_per_class = {i: target for i in range(len(class_names))}

# Initialize counters more efficiently
new_class_elements = {i: 0 for i in range(len(class_names))}   # Dictionary for the new classes and their # of samples
class_elements = class_counts_dict.copy()  # Start with original counts

# Calculating which classes need augmentation
# If the target is smaller than the number of samples in some classes,
# those classes won't need any augmentation and will be subject to downsampling

if class_counts.max() >= target:
  if class_counts.min() >= target:
    classes_to_modify = {i for i in range(len(class_names))}
    print("All classes will undergo downsampling")
    classes_needing_aug = {i for i in range(len(class_names)) if class_counts_dict.get(i, 0) < target}
    new_class_aug_elements = {i: 0 for i in range(len(class_names))}

  else:
    classes_needing_aug = {i for i in range(len(class_names)) if class_counts_dict.get(i, 0) < target}
    classes_to_modify = {i for i in range(len(class_names)) if class_counts_dict.get(i, 0) < target or class_counts_dict.get(i,0) > target}
    new_class_aug_elements = {i: (target - class_counts.values[i]) for i in range(len(class_names)) if target - class_counts.values[i] > 0} # Calculating the number of augmented images needed for the underrappresented classes to reach the target
    aug_elements_dict = {k: int(v) for k, v in new_class_aug_elements.items()}   # Making the values int variables

# If the target is grater than the greatest number of samples recorded,
# all classes will be subject to data augmentation
if class_counts.max() < target:
  classes_needing_aug = {i for i in range(len(class_names))}
  new_class_aug_elements = {i: target - class_counts.values[i]for i in range(len(class_names))}
  aug_elements_dict = {k: int(v) for k, v in new_class_aug_elements.items()}
  print("All classes will undergo data augmentation")

print("Classes needing augmentation:")
for idx in classes_needing_aug:
    print(f"{class_names[idx]}")

print(f"Target images per class: {target}")
print(f"Classes undergoing data augmentation: {len(classes_needing_aug)}")
print(f"Classes undergoing downsampling: {len(classes_to_modify) - len(classes_needing_aug)}")

# Add progress tracking
from tqdm.notebook import tqdm

# Data manipulation loop
total_needed = sum(max(0, target - class_counts_dict.get(i, 0)) for i in range(len(class_names)))
pbar = tqdm(total=total_needed, desc="Adding images")
print(f"Total needed: {total_needed}")

# Saving images loop
total_saved = target*len(class_names)
pbar1 = tqdm(total = total_saved, desc="Saving images")
print(f"Total saved: {total_saved}")


# Use enumerate with early stopping
for i, (image, label) in enumerate(ds_train.repeat()):
    label_index = label.numpy()
    label_name = class_names[label_index]
    print(f"class #{i+1}: {class_names[label_index]}")

    # Early termination check - if no more classes need more samples
    if all(count >= target for count in new_class_elements.values()):
      print(f" All classes have {target} images.")
      print("Current class counts:", new_class_elements)
      break

    # Checking if this specific class still needs samples
    if new_class_elements[label_index] >= target:
      if label_index in classes_needing_aug:
        classes_needing_aug.discard(label_index)
        continue
      continue

    # Always save the original image first
    save_path = os.path.join(output_root, label_name, f'img_{new_class_elements[label_index]}.png')
    tf.keras.preprocessing.image.save_img(save_path, image.numpy())

    # Update counters following the addition of one image
    new_class_elements[label_index] += 1
    pbar1.update(1)

    print(f"Original Image saved in class: {class_names[label_index]}")
    #print(f"Nella lista delle classi in need: {classes_needing_aug[label_index]}")

    # Checking if a specific class still needs augmented samples
    if label_index in classes_needing_aug:
      if aug_elements_dict[label_index] == 0:
        continue

    # Termination check - if this class is done, skip augmentation
    if new_class_elements[label_index] >= target:
      print(f"Class does not need anymore samples: {class_names[label_index]}")
      if label_index in classes_needing_aug:
        # Remove from classes needing augmentation
        classes_needing_aug.discard(label_index)
        continue
      continue

    # Only augment if this class still needs more samples
    if label_index in classes_needing_aug and new_class_elements[label_index] < target:
      # Apply augmentation with TensorFlow operations (faster than sequential)
      # Convert to float32 for augmentation operations
      aug_image = augment(image)

      # Convert back to uint8
      #aug_image = tf.clip_by_value(aug_image, 0.0, 255.0)
      aug_image = tf.cast(aug_image, tf.uint8)

      # Save augmented image
      save_path_aug = os.path.join(output_root, label_name, f'aug_{new_class_elements[label_index]}.png')
      tf.keras.preprocessing.image.save_img(save_path_aug, aug_image.numpy())
      print(f"Aug image saved in class: {class_names[label_index]}")

      # Update counters following the augmatation of one image
      class_elements[label_index] += 1
      new_class_aug_elements[label_index] -= 1
      new_class_elements[label_index] += 1
      aug_elements_dict[label_index] -= 1
      pbar.update(1)
      pbar1.update(1)

pbar.close()
pbar1.close()

# Print final statistics
print("\nFinal class distribution:")
for idx, count in new_class_elements.items():
    print(f"{class_names[idx]}: {count} images")

total_obtained = sum(new_class_elements.values())
print(f"Total samples in dataset: {total_obtained}")
# Out:
# Classes needing augmentation:
# Apple___Apple_scab
# Apple___Black_rot
# Apple___Cedar_apple_rust
# Apple___healthy
# Blueberry___healthy
# Cherry___healthy
# Cherry___Powdery_mildew
# Corn___Cercospora_leaf_spot Gray_leaf_spot
# Corn___Common_rust
# Corn___healthy
# Corn___Northern_Leaf_Blight
# Grape___Black_rot
# Grape___Esca_(Black_Measles)
# Grape___healthy
# Grape___Leaf_blight_(Isariopsis_Leaf_Spot)
# Peach___Bacterial_spot
# Peach___healthy
# Pepper,_bell___Bacterial_spot
# Pepper,_bell___healthy
# Potato___Early_blight
# Potato___healthy
# Potato___Late_blight
# Raspberry___healthy
# Soybean___healthy
# Squash___Powdery_mildew
# Strawberry___healthy
# Strawberry___Leaf_scorch
# Tomato___Bacterial_spot
# Tomato___Early_blight
# Tomato___healthy
# Tomato___Late_blight
# Tomato___Leaf_Mold
# Tomato___Septoria_leaf_spot
# Tomato___Spider_mites Two-spotted_spider_mite
# Tomato___Target_Spot
# Tomato___Tomato_mosaic_virus
# Tomato___Tomato_Yellow_Leaf_Curl_Virus
# Target images per class: 4399
# Classes undergoing data augmentation: 37
# Classes undergoing downsampling: 0
# Adding images:   0%|          | 0/123720 [00:00<?, ?it/s]
# Total needed: 123720
# Saving images:   0%|          | 0/167162 [00:00<?, ?it/s]
# Total saved: 167162
# class #1: Tomato___Septoria_leaf_spot
# Original Image saved in class: Tomato___Septoria_leaf_spot
# Aug image saved in class: Tomato___Septoria_leaf_spot
# class #2: Tomato___Early_blight
# Original Image saved in class: Tomato___Early_blight
# Aug image saved in class: Tomato___Early_blight
# class #3: Squash___Powdery_mildew
# Original Image saved in class: Squash___Powdery_mildew
# Aug image saved in class: Squash___Powdery_mildew
# class #4: Peach___Bacterial_spot
# Original Image saved in class: Peach___Bacterial_spot
# Aug image saved in class: Peach___Bacterial_spot
# class #5: Tomato___Leaf_Mold
# Original Image saved in class: Tomato___Leaf_Mold
# Aug image saved in class: Tomato___Leaf_Mold
# class #6: Orange___Haunglongbing_(Citrus_greening)
# Original Image saved in class: Orange___Haunglongbing_(Citrus_greening)
# class #7: Soybean___healthy
# Original Image saved in class: Soybean___healthy
# Aug image saved in class: Soybean___healthy
# class #8: Peach___Bacterial_spot
# Original Image saved in class: Peach___Bacterial_spot
# Aug image saved in class: Peach___Bacterial_spot
# class #9: Strawberry___Leaf_scorch
# Original Image saved in class: Strawberry___Leaf_scorch
# Aug image saved in class: Strawberry___Leaf_scorch
# class #10: Apple___Apple_scab

# %%
if augmentation_type != 'sampl':
  #import os
  #import random
  #import matplotlib.pyplot as plt
  from tensorflow.keras.preprocessing import image
  #import tensorflow as tf

  # Function to load and preprocess image
  def load_image(image_path):
      img = image.load_img(image_path, target_size=(224, 224))  # Adjust size if necessary
      img = image.img_to_array(img)  # Convert to array
      img = tf.convert_to_tensor(img)  # Convert to tensor
      return img

  # Randomly pick a class from the list
  selected_class = random.choice(class_names)

  # List the original and augmented images for the selected class
  class_folder = os.path.join(output_root, selected_class)

  # List original and augmented images based on filenames
  original_images = [f for f in os.listdir(class_folder) if f.startswith('img_') and f.endswith('.png')]
  augmented_images = [f for f in os.listdir(class_folder) if f.startswith('aug_') and f.endswith('.png')]

  # Select random images (one original and one augmented)
  original_image_file = random.choice(original_images)
  augmented_image_file = random.choice(augmented_images)

  # Load the images
  original_image = load_image(os.path.join(class_folder, original_image_file))
  augmented_image = load_image(os.path.join(class_folder, augmented_image_file))

  # Plot the original and augmented images side by side
  plt.figure(figsize=(10, 5))

  # Original Image Plot
  plt.subplot(1, 2, 1)
  plt.imshow(original_image.numpy().astype('uint8'))
  plt.title(f"Original - {selected_class}")
  plt.axis('off')  # Hide axes for a cleaner look

  # Augmented Image Plot
  plt.subplot(1, 2, 2)
  plt.imshow(augmented_image.numpy().astype('uint8'))
  plt.title(f"Augmented - {selected_class}")
  plt.axis('off')

  plt.show()

# %%
# Class distribution after augmentation
plt.figure(figsize=(12,6))
plt.bar(class_names, new_class_elements.values())
plt.title("Class distribution after augmentation")
plt.xlabel("Class")
plt.ylabel("Number of images")
plt.xticks(rotation=90)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-875633682.py in <cell line: 0>()
#       1 # Class distribution after augmentation
#       2 plt.figure(figsize=(12,6))
# ----> 3 plt.bar(class_names, new_class_elements.values())
#       4 plt.title("Class distribution after augmentation")
#       5 plt.xlabel("Class")
#
# NameError: name 'new_class_elements' is not defined

# %% [markdown]
# # MODEL TRAINING

# %%
# Loading the new training set from chosen dir

from tensorflow.keras.utils import image_dataset_from_directory

# Define the path to the augmented data
augmented_data_path = output_root

# Load the dataset from the new directory
ds_augmented_train = tf.keras.utils.image_dataset_from_directory(
    augmented_data_path,
    labels='inferred',
    label_mode='categorical',   # one-hot encoding
    batch_size=32,
    image_size=(224, 224),      # before preprocessing
    shuffle=True,
    seed=123
)

# Class names
class_names = sorted(os.listdir(augmented_data_path))
print("Class names:", class_names)

# Counting the images per class to check that the augmentation was successful
class_counts = {cls: len(os.listdir(os.path.join(augmented_data_path, cls))) for cls in class_names}

print("Number of images per class:")
for cls in class_names:
    print(f"{cls}: {class_counts[cls]} images")
# Out:
# Found 7600 files belonging to 38 classes.
# Class names: ['Apple___Apple_scab', 'Apple___Black_rot', 'Apple___Cedar_apple_rust', 'Apple___healthy', 'Blueberry___healthy', 'Cherry___Powdery_mildew', 'Cherry___healthy', 'Corn___Cercospora_leaf_spot Gray_leaf_spot', 'Corn___Common_rust', 'Corn___Northern_Leaf_Blight', 'Corn___healthy', 'Grape___Black_rot', 'Grape___Esca_(Black_Measles)', 'Grape___Leaf_blight_(Isariopsis_Leaf_Spot)', 'Grape___healthy', 'Orange___Haunglongbing_(Citrus_greening)', 'Peach___Bacterial_spot', 'Peach___healthy', 'Pepper,_bell___Bacterial_spot', 'Pepper,_bell___healthy', 'Potato___Early_blight', 'Potato___Late_blight', 'Potato___healthy', 'Raspberry___healthy', 'Soybean___healthy', 'Squash___Powdery_mildew', 'Strawberry___Leaf_scorch', 'Strawberry___healthy', 'Tomato___Bacterial_spot', 'Tomato___Early_blight', 'Tomato___Late_blight', 'Tomato___Leaf_Mold', 'Tomato___Septoria_leaf_spot', 'Tomato___Spider_mites Two-spotted_spider_mite', 'Tomato___Target_Spot', 'Tomato___Tomato_Yellow_Leaf_Curl_Virus', 'Tomato___Tomato_mosaic_virus', 'Tomato___healthy']
# Number of images per class:
# Apple___Apple_scab: 200 images
# Apple___Black_rot: 200 images
# Apple___Cedar_apple_rust: 200 images
# Apple___healthy: 200 images
# Blueberry___healthy: 200 images
# Cherry___Powdery_mildew: 200 images
# Cherry___healthy: 200 images
# Corn___Cercospora_leaf_spot Gray_leaf_spot: 200 images
# Corn___Common_rust: 200 images
# Corn___Northern_Leaf_Blight: 200 images
# Corn___healthy: 200 images
# Grape___Black_rot: 200 images
# Grape___Esca_(Black_Measles): 200 images
# Grape___Leaf_blight_(Isariopsis_Leaf_Spot): 200 images
# Grape___healthy: 200 images
# Orange___Haunglongbing_(Citrus_greening): 200 images
# Peach___Bacterial_spot: 200 images
# Peach___healthy: 200 images
# Pepper,_bell___Bacterial_spot: 200 images
# Pepper,_bell___healthy: 200 images
# Potato___Early_blight: 200 images
# Potato___Late_blight: 200 images
# Potato___healthy: 200 images
# Raspberry___healthy: 200 images
# Soybean___healthy: 200 images
# Squash___Powdery_mildew: 200 images
# Strawberry___Leaf_scorch: 200 images
# Strawberry___healthy: 200 images
# Tomato___Bacterial_spot: 200 images
# Tomato___Early_blight: 200 images
# Tomato___Late_blight: 200 images
# Tomato___Leaf_Mold: 200 images
# Tomato___Septoria_leaf_spot: 200 images
# Tomato___Spider_mites Two-spotted_spider_mite: 200 images
# Tomato___Target_Spot: 200 images
# Tomato___Tomato_Yellow_Leaf_Curl_Virus: 200 images
# Tomato___Tomato_mosaic_virus: 200 images
# Tomato___healthy: 200 images

# %%
# setup constants
NUM_CLASSES         = ds_info.features['label'].num_classes

COMMON_FILENAME = augmentation_type+'_aug_'+ samplesize

WEIGHTS_DIR = '/content/drive/MyDrive/progetto-daml/weights'
HISTORY_DIR = '/content/drive/MyDrive/progetto-daml/train-hist'
os.makedirs(WEIGHTS_DIR, exist_ok=True)
os.makedirs(HISTORY_DIR, exist_ok=True)
CHECKPOINT_FILE = f'{WEIGHTS_DIR}/{COMMON_FILENAME}.h5'
HISTORY_FILE = f'{HISTORY_DIR}/history_{COMMON_FILENAME}'

IMG_SIZE            = (128, 128) # Image size for resizing in preprocessing
IMG_CHANNELS        = 3          # Number of channels in the images (RGB)
BATCH_SIZE          = 64         # Batch size for training
N_EPOCHS            = 50         # Number of epochs for training
STARTING_LR         = 0.0002     # Starting learning rate for the optimizer
EARLY_STOP_PATIENCE = 4          # Patience for early stopping
REDUCE_LR_PATIENCE  = 3          # Patience for reducing learning rate

# %%
# Preprocessing
train_ds = ds_augmented_train.map(lambda image, label: preprocess_aug(image, label), num_parallel_calls=tf.data.AUTOTUNE).prefetch(tf.data.AUTOTUNE)
val_ds   = ds_val.map  (lambda image, label: preprocess(image, label, ds_info, IMG_SIZE), num_parallel_calls=tf.data.AUTOTUNE).batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)
#test_ds  = ds_test.map (lambda image, label: preprocess(image, label, ds_info, IMG_SIZE), num_parallel_calls=tf.data.AUTOTUNE).batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)

# %% [markdown]
# ## Base model

# %%
from keras.models import Sequential, Model
from keras.layers import Activation, BatchNormalization, Dense, Conv2D, MaxPooling2D, Dropout, Flatten, GlobalAveragePooling2D, ReLU, Rescaling
from keras.optimizers.legacy import Adam, SGD
from keras.losses import CategoricalCrossentropy

from keras.metrics import CategoricalAccuracy, Precision, Recall
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau

def simple_cnn(input_shape=(IMG_SIZE[0], IMG_SIZE[1], 3), num_classes=38):
    model = Sequential([
        Conv2D(16, (3, 3), activation='relu', padding='same'),
        Dropout(0.4),
        MaxPooling2D((2, 2)),
        Conv2D(32, (3, 3), activation='relu', padding='same'),
        MaxPooling2D((2, 2)),
        Flatten(),
        Dense(num_classes, activation='softmax')
    ])
    return model

# %%
model = simple_cnn()
model.build(input_shape=(None, IMG_SIZE[0], IMG_SIZE[1], 3))  # Build the model with the input shape
model.summary()
# Out:
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_3 (Conv2D)               │ (None, 128, 128, 16)   │           448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 128, 128, 16)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 64, 64, 16)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 64, 64, 32)     │         4,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_4 (MaxPooling2D)  │ (None, 32, 32, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 32768)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 38)             │     1,245,222 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,250,310 (4.77 MB)
#  Trainable params: 1,250,310 (4.77 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Model training
from tensorflow.keras.optimizers import Adam
optimizer = Adam(learning_rate=STARTING_LR)
model.compile(
    optimizer=optimizer,
    loss=CategoricalCrossentropy(),
    metrics=['accuracy']
)

n_epochs = N_EPOCHS

history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=N_EPOCHS,
    callbacks=[
        EarlyStopping(monitor='val_accuracy',
                      patience=EARLY_STOP_PATIENCE,
                      restore_best_weights=True,
                      verbose=1),
        ModelCheckpoint(CHECKPOINT_FILE,
                        monitor='val_accuracy', save_best_only=True,
                        verbose=1),
        ReduceLROnPlateau(monitor='val_accuracy',
                          factor=0.2, patience=REDUCE_LR_PATIENCE,
                          verbose=1,)
    ]
)
# Out:
# Epoch 1/50
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.1686 - loss: 3.2757
# Epoch 1: val_accuracy improved from -inf to 0.31983, saving model to /content/drive/MyDrive/progetto-daml/weights/sampl_aug_200.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 21s 68ms/step - accuracy: 0.1692 - loss: 3.2730 - val_accuracy: 0.3198 - val_loss: 2.8457 - learning_rate: 2.0000e-04
# Epoch 2/50
# 237/238 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.5808 - loss: 1.5044
# Epoch 2: val_accuracy improved from 0.31983 to 0.33751, saving model to /content/drive/MyDrive/progetto-daml/weights/sampl_aug_200.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 11s 48ms/step - accuracy: 0.5810 - loss: 1.5033 - val_accuracy: 0.3375 - val_loss: 2.8938 - learning_rate: 2.0000e-04
# Epoch 3/50
# 237/238 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.6798 - loss: 1.1004
# Epoch 3: val_accuracy improved from 0.33751 to 0.35389, saving model to /content/drive/MyDrive/progetto-daml/weights/sampl_aug_200.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 12s 51ms/step - accuracy: 0.6800 - loss: 1.0999 - val_accuracy: 0.3539 - val_loss: 2.9640 - learning_rate: 2.0000e-04
# Epoch 4/50
# 237/238 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.7503 - loss: 0.8714
# Epoch 4: val_accuracy improved from 0.35389 to 0.36734, saving model to /content/drive/MyDrive/progetto-daml/weights/sampl_aug_200.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 11s 48ms/step - accuracy: 0.7505 - loss: 0.8710 - val_accuracy: 0.3673 - val_loss: 3.0369 - learning_rate: 2.0000e-04
# Epoch 5/50
# 237/238 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.8029 - loss: 0.6804
# Epoch 5: val_accuracy improved from 0.36734 to 0.37415, saving model to /content/drive/MyDrive/progetto-daml/weights/sampl_aug_200.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 12s 49ms/step - accuracy: 0.8029 - loss: 0.6802 - val_accuracy: 0.3741 - val_loss: 3.1561 - learning_rate: 2.0000e-04
# Epoch 6/50
# 237/238 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.8392 - loss: 0.5475
# Epoch 6: val_accuracy improved from 0.37415 to 0.38612, saving model to /content/drive/MyDrive/progetto-daml/weights/sampl_aug_200.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 12s 48ms/step - accuracy: 0.8393 - loss: 0.5474 - val_accuracy: 0.3861 - val_loss: 3.2604 - learning_rate: 2.0000e-04
# Epoch 7/50
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.8761 - loss: 0.4317
# Epoch 7: val_accuracy improved from 0.38612 to 0.38722, saving model to /content/drive/MyDrive/progetto-daml/weights/sampl_aug_200.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 12s 49ms/step - accuracy: 0.8761 - loss: 0.4316 - val_accuracy: 0.3872 - val_loss: 3.3546 - learning_rate: 2.0000e-04
# Epoch 8/50
# 237/238 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.9072 - loss: 0.3540
# Epoch 8: val_accuracy improved from 0.38722 to 0.40416, saving model to /content/drive/MyDrive/progetto-daml/weights/sampl_aug_200.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 12s 49ms/step - accuracy: 0.9072 - loss: 0.3539 - val_accuracy: 0.4042 - val_loss: 3.5080 - learning_rate: 2.0000e-04
# Epoch 9/50
# 237/238 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.9364 - loss: 0.2675
# Epoch 9: val_accuracy improved from 0.40416 to 0.40876, saving model to /content/drive/MyDrive/progetto-daml/weights/sampl_aug_200.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 12s 49ms/step - accuracy: 0.9365 - loss: 0.2674 - val_accuracy: 0.4088 - val_loss: 3.6102 - learning_rate: 2.0000e-04
# Epoch 10/50
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.9543 - loss: 0.2065
# Epoch 10: val_accuracy did not improve from 0.40876
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 12s 48ms/step - accuracy: 0.9543 - loss: 0.2065 - val_accuracy: 0.3916 - val_loss: 3.7392 - learning_rate: 2.0000e-04
# Epoch 11/50
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.9601 - loss: 0.1791
# Epoch 11: val_accuracy did not improve from 0.40876
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 11s 47ms/step - accuracy: 0.9602 - loss: 0.1790 - val_accuracy: 0.3988 - val_loss: 3.9543 - learning_rate: 2.0000e-04
# Epoch 12/50
# 236/238 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.9782 - loss: 0.1292
# Epoch 12: val_accuracy improved from 0.40876 to 0.41944, saving model to /content/drive/MyDrive/progetto-daml/weights/sampl_aug_200.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 12s 49ms/step - accuracy: 0.9782 - loss: 0.1292 - val_accuracy: 0.4194 - val_loss: 4.0119 - learning_rate: 2.0000e-04
# Epoch 13/50
# 237/238 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.9851 - loss: 0.1014
# Epoch 13: val_accuracy did not improve from 0.41944
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 11s 48ms/step - accuracy: 0.9851 - loss: 0.1013 - val_accuracy: 0.4141 - val_loss: 4.1887 - learning_rate: 2.0000e-04
# Epoch 14/50
# 237/238 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.9858 - loss: 0.0818
# Epoch 14: val_accuracy improved from 0.41944 to 0.42092, saving model to /content/drive/MyDrive/progetto-daml/weights/sampl_aug_200.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 12s 49ms/step - accuracy: 0.9858 - loss: 0.0817 - val_accuracy: 0.4209 - val_loss: 4.2993 - learning_rate: 2.0000e-04
# Epoch 15/50
# 236/238 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.9955 - loss: 0.0567
# Epoch 15: val_accuracy improved from 0.42092 to 0.42810, saving model to /content/drive/MyDrive/progetto-daml/weights/sampl_aug_200.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 12s 49ms/step - accuracy: 0.9955 - loss: 0.0567 - val_accuracy: 0.4281 - val_loss: 4.5365 - learning_rate: 2.0000e-04
# Epoch 16/50
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.9969 - loss: 0.0463
# Epoch 16: val_accuracy improved from 0.42810 to 0.42847, saving model to /content/drive/MyDrive/progetto-daml/weights/sampl_aug_200.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 12s 49ms/step - accuracy: 0.9969 - loss: 0.0462 - val_accuracy: 0.4285 - val_loss: 4.6859 - learning_rate: 2.0000e-04
# Epoch 17/50
# 236/238 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.9961 - loss: 0.0409
# Epoch 17: val_accuracy improved from 0.42847 to 0.42883, saving model to /content/drive/MyDrive/progetto-daml/weights/sampl_aug_200.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 12s 50ms/step - accuracy: 0.9961 - loss: 0.0409 - val_accuracy: 0.4288 - val_loss: 4.7551 - learning_rate: 2.0000e-04
# Epoch 18/50
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.9990 - loss: 0.0297
# Epoch 18: val_accuracy improved from 0.42883 to 0.43565, saving model to /content/drive/MyDrive/progetto-daml/weights/sampl_aug_200.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 12s 49ms/step - accuracy: 0.9990 - loss: 0.0297 - val_accuracy: 0.4356 - val_loss: 4.8756 - learning_rate: 2.0000e-04
# Epoch 19/50
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.9978 - loss: 0.0268
# Epoch 19: val_accuracy did not improve from 0.43565
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 12s 49ms/step - accuracy: 0.9978 - loss: 0.0268 - val_accuracy: 0.4159 - val_loss: 4.9485 - learning_rate: 2.0000e-04
# Epoch 20/50
# 237/238 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.9941 - loss: 0.0349
# Epoch 20: val_accuracy did not improve from 0.43565
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 11s 47ms/step - accuracy: 0.9941 - loss: 0.0351 - val_accuracy: 0.4152 - val_loss: 4.8946 - learning_rate: 2.0000e-04
# Epoch 21/50
# 237/238 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.9874 - loss: 0.0570
# Epoch 21: val_accuracy did not improve from 0.43565
#
# Epoch 21: ReduceLROnPlateau reducing learning rate to 3.9999998989515007e-05.
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 11s 47ms/step - accuracy: 0.9874 - loss: 0.0570 - val_accuracy: 0.4040 - val_loss: 5.1195 - learning_rate: 2.0000e-04
# Epoch 22/50
# 236/238 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.9989 - loss: 0.0203
# Epoch 22: val_accuracy did not improve from 0.43565
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 11s 47ms/step - accuracy: 0.9989 - loss: 0.0202 - val_accuracy: 0.4270 - val_loss: 5.0043 - learning_rate: 4.0000e-05
# Epoch 22: early stopping
# Restoring model weights from the end of the best epoch: 18.

# %%
model.save('/content/drive/MyDrive/progetto-daml/model'+ augmentation_type+'_aug_'+ samplesize+'.keras')

# %%
import pickle
with open(HISTORY_FILE+'.pkl', 'wb') as f:
    pickle.dump(history.history, f)

# %%
# !mkdir -p src
# !cp /content/drive/MyDrive/progetto-daml/src/preprocessing.py src/
# !cp /content/drive/MyDrive/progetto-daml/src/plotting.py src/plotting.py

# %%
import sys
sys.path.append('/content/src')

# %%
# Plotting the train. history
from plotting import plot_model_history

plot_model_history(history)
plt.savefig(HISTORY_FILE+'.png', dpi=400, bbox_inches='tight')

# %% [markdown]
# Best Architecture created

# %%
# Skip bad samples automatically during training
# train_ds = train_ds.apply(tf.data.experimental.ignore_errors())
# val_ds   = val_ds.apply(tf.data.experimental.ignore_errors())
# Out:
# WARNING:tensorflow:From /tmp/ipython-input-209070515.py:2: ignore_errors (from tensorflow.python.data.experimental.ops.error_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.ignore_errors` instead.

# %%
from keras.models import Sequential, Model
from keras.layers import Activation, BatchNormalization, Dense, Conv2D, MaxPooling2D, Dropout, Flatten, GlobalAveragePooling2D, ReLU, Rescaling
from keras.optimizers.legacy import Adam, SGD
from keras.losses import CategoricalCrossentropy

from keras.metrics import CategoricalAccuracy, Precision, Recall
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau

COMMON_FILENAME = 'v1_'+ augmentation_type+'_aug_'+ samplesize

WEIGHTS_DIR = '/content/drive/MyDrive/progetto-daml/weights'
HISTORY_DIR = '/content/drive/MyDrive/progetto-daml/train-hist'
os.makedirs(WEIGHTS_DIR, exist_ok=True)
os.makedirs(HISTORY_DIR, exist_ok=True)
CHECKPOINT_FILE = f'{WEIGHTS_DIR}/{COMMON_FILENAME}.h5'
HISTORY_FILE = f'{HISTORY_DIR}/history_{COMMON_FILENAME}'

def simple_cnn_v1(input_shape=(IMG_SIZE[0], IMG_SIZE[1], 3), num_classes=38):
    model = Sequential([
        Conv2D(16, (3, 3), activation='relu', padding='same'),
        Dropout(0.4),
        MaxPooling2D((2, 2)),
        Conv2D(32, (3, 3), activation='relu', padding='same'),
        MaxPooling2D((2, 2)),
        Dropout(0.4),
        Conv2D(64, (3, 3), activation='relu', padding='same'),
        MaxPooling2D((2, 2)),
        Dropout(0.4),
        Flatten(),
        Dense(num_classes, activation='softmax')
    ])
    return model

# %%
model = simple_cnn_v1()
model.build(input_shape=(None, IMG_SIZE[0], IMG_SIZE[1], 3))  # Build the model with the input shape
model.summary()
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 128, 128, 16)   │           448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128, 128, 16)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 64, 64, 16)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 64, 64, 32)     │         4,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 32, 32, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 32, 32, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 32, 32, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 16, 16, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 16, 16, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 16384)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 38)             │       622,630 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 646,214 (2.47 MB)
#  Trainable params: 646,214 (2.47 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
from tensorflow.keras.optimizers import Adam
optimizer = Adam(learning_rate=STARTING_LR)
model.compile(
    optimizer=optimizer,
    loss=CategoricalCrossentropy(),
    metrics=['accuracy']
)

n_epochs = N_EPOCHS

history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=N_EPOCHS,
    callbacks=[
        EarlyStopping(monitor='val_accuracy',
                      patience=EARLY_STOP_PATIENCE,
                      restore_best_weights=True,
                      verbose=1),
        ModelCheckpoint(CHECKPOINT_FILE,
                        monitor='val_accuracy', save_best_only=True,
                        verbose=1),
        ReduceLROnPlateau(monitor='val_accuracy',
                          factor=0.2, patience=REDUCE_LR_PATIENCE,
                          verbose=1,)
    ]
)
# Out:
# Epoch 1/50
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 0s 680ms/step - accuracy: 0.0833 - loss: 3.4832
# Epoch 1: val_accuracy improved from -inf to 0.28485, saving model to /content/drive/MyDrive/progetto-daml/weights/v1_sampl_aug_200.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 173s 689ms/step - accuracy: 0.0837 - loss: 3.4813 - val_accuracy: 0.2848 - val_loss: 3.0318 - learning_rate: 2.0000e-04
# Epoch 2/50
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.4624 - loss: 1.8883
# Epoch 2: val_accuracy improved from 0.28485 to 0.31504, saving model to /content/drive/MyDrive/progetto-daml/weights/v1_sampl_aug_200.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 12s 49ms/step - accuracy: 0.4626 - loss: 1.8874 - val_accuracy: 0.3150 - val_loss: 2.9318 - learning_rate: 2.0000e-04
# Epoch 3/50
# 237/238 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.6264 - loss: 1.2959
# Epoch 3: val_accuracy did not improve from 0.31504
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 11s 48ms/step - accuracy: 0.6266 - loss: 1.2952 - val_accuracy: 0.3130 - val_loss: 3.0522 - learning_rate: 2.0000e-04
# Epoch 4/50
# 237/238 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.6993 - loss: 1.0405
# Epoch 4: val_accuracy improved from 0.31504 to 0.35481, saving model to /content/drive/MyDrive/progetto-daml/weights/v1_sampl_aug_200.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 12s 50ms/step - accuracy: 0.6994 - loss: 1.0401 - val_accuracy: 0.3548 - val_loss: 3.1189 - learning_rate: 2.0000e-04
# Epoch 5/50
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.7441 - loss: 0.8615
# Epoch 5: val_accuracy improved from 0.35481 to 0.40048, saving model to /content/drive/MyDrive/progetto-daml/weights/v1_sampl_aug_200.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 12s 50ms/step - accuracy: 0.7441 - loss: 0.8614 - val_accuracy: 0.4005 - val_loss: 3.2642 - learning_rate: 2.0000e-04
# Epoch 6/50
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.7721 - loss: 0.7311
# Epoch 6: val_accuracy did not improve from 0.40048
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 11s 48ms/step - accuracy: 0.7722 - loss: 0.7311 - val_accuracy: 0.3909 - val_loss: 3.3912 - learning_rate: 2.0000e-04
# Epoch 7/50
# 237/238 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.8078 - loss: 0.6427
# Epoch 7: val_accuracy improved from 0.40048 to 0.40784, saving model to /content/drive/MyDrive/progetto-daml/weights/v1_sampl_aug_200.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 12s 49ms/step - accuracy: 0.8078 - loss: 0.6426 - val_accuracy: 0.4078 - val_loss: 3.5468 - learning_rate: 2.0000e-04
# Epoch 8/50
# 237/238 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.8164 - loss: 0.5754
# Epoch 8: val_accuracy improved from 0.40784 to 0.41797, saving model to /content/drive/MyDrive/progetto-daml/weights/v1_sampl_aug_200.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 12s 49ms/step - accuracy: 0.8165 - loss: 0.5753 - val_accuracy: 0.4180 - val_loss: 3.6909 - learning_rate: 2.0000e-04
# Epoch 9/50
# 236/238 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.8393 - loss: 0.5206
# Epoch 9: val_accuracy improved from 0.41797 to 0.41926, saving model to /content/drive/MyDrive/progetto-daml/weights/v1_sampl_aug_200.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 12s 48ms/step - accuracy: 0.8394 - loss: 0.5203 - val_accuracy: 0.4193 - val_loss: 3.7437 - learning_rate: 2.0000e-04
# Epoch 10/50
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.8618 - loss: 0.4457
# Epoch 10: val_accuracy improved from 0.41926 to 0.42957, saving model to /content/drive/MyDrive/progetto-daml/weights/v1_sampl_aug_200.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 11s 48ms/step - accuracy: 0.8618 - loss: 0.4456 - val_accuracy: 0.4296 - val_loss: 3.9934 - learning_rate: 2.0000e-04
# Epoch 11/50
# 237/238 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.8726 - loss: 0.4126
# Epoch 11: val_accuracy did not improve from 0.42957
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 11s 48ms/step - accuracy: 0.8726 - loss: 0.4125 - val_accuracy: 0.4159 - val_loss: 4.2255 - learning_rate: 2.0000e-04
# Epoch 12/50
# 237/238 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.8731 - loss: 0.3935
# Epoch 12: val_accuracy improved from 0.42957 to 0.43031, saving model to /content/drive/MyDrive/progetto-daml/weights/v1_sampl_aug_200.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 12s 49ms/step - accuracy: 0.8731 - loss: 0.3934 - val_accuracy: 0.4303 - val_loss: 4.3565 - learning_rate: 2.0000e-04
# Epoch 13/50
# 236/238 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.8967 - loss: 0.3372
# Epoch 13: val_accuracy improved from 0.43031 to 0.44909, saving model to /content/drive/MyDrive/progetto-daml/weights/v1_sampl_aug_200.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 11s 48ms/step - accuracy: 0.8967 - loss: 0.3370 - val_accuracy: 0.4491 - val_loss: 4.4711 - learning_rate: 2.0000e-04
# Epoch 14/50
# 237/238 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.9057 - loss: 0.3108
# Epoch 14: val_accuracy did not improve from 0.44909
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 11s 47ms/step - accuracy: 0.9058 - loss: 0.3107 - val_accuracy: 0.4432 - val_loss: 4.6609 - learning_rate: 2.0000e-04
# Epoch 15/50
# 237/238 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.9064 - loss: 0.2802
# Epoch 15: val_accuracy did not improve from 0.44909
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 11s 47ms/step - accuracy: 0.9064 - loss: 0.2802 - val_accuracy: 0.4485 - val_loss: 4.7956 - learning_rate: 2.0000e-04
# Epoch 16/50
# 236/238 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.9128 - loss: 0.2676
# Epoch 16: val_accuracy improved from 0.44909 to 0.46732, saving model to /content/drive/MyDrive/progetto-daml/weights/v1_sampl_aug_200.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 12s 49ms/step - accuracy: 0.9128 - loss: 0.2675 - val_accuracy: 0.4673 - val_loss: 5.0216 - learning_rate: 2.0000e-04
# Epoch 17/50
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.9278 - loss: 0.2315
# Epoch 17: val_accuracy did not improve from 0.46732
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 11s 47ms/step - accuracy: 0.9278 - loss: 0.2315 - val_accuracy: 0.4495 - val_loss: 5.3072 - learning_rate: 2.0000e-04
# Epoch 18/50
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.9288 - loss: 0.2134
# Epoch 18: val_accuracy did not improve from 0.46732
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 11s 47ms/step - accuracy: 0.9288 - loss: 0.2134 - val_accuracy: 0.4334 - val_loss: 5.4308 - learning_rate: 2.0000e-04
# Epoch 19/50
# 237/238 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.9345 - loss: 0.2015
# Epoch 19: val_accuracy did not improve from 0.46732
#
# Epoch 19: ReduceLROnPlateau reducing learning rate to 3.9999998989515007e-05.
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 11s 47ms/step - accuracy: 0.9345 - loss: 0.2015 - val_accuracy: 0.4537 - val_loss: 5.3763 - learning_rate: 2.0000e-04
# Epoch 20/50
# 237/238 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.9560 - loss: 0.1383
# Epoch 20: val_accuracy did not improve from 0.46732
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 11s 48ms/step - accuracy: 0.9561 - loss: 0.1382 - val_accuracy: 0.4421 - val_loss: 5.5510 - learning_rate: 4.0000e-05
# Epoch 20: early stopping
# Restoring model weights from the end of the best epoch: 16.

# %%
model.save('/content/drive/MyDrive/progetto-daml/model_v1'+ augmentation_type+'_aug_'+ samplesize+'.keras')

# %%
import pickle
with open(HISTORY_FILE+'.pkl', 'wb') as f:
    pickle.dump(history.history, f)

# %%
# !mkdir -p src
# !cp /content/drive/MyDrive/progetto-daml/src/preprocessing.py src/
# !cp /content/drive/MyDrive/progetto-daml/src/plotting.py src/plotting.py

# %%
import sys
sys.path.append('/content/src')

# %%
# Plotting the train. history
from plotting import plot_model_history

plot_model_history(history)
plt.savefig(HISTORY_FILE+'.png', dpi=400, bbox_inches='tight')

# %% [markdown]
# ## MOBILENET

# %%
from keras.models import Sequential, Model
from keras.layers import Activation, BatchNormalization, Dense, Conv2D, MaxPooling2D, Dropout, Flatten, GlobalAveragePooling2D, ReLU, Rescaling, Input
from keras.optimizers.legacy import Adam, SGD
from tensorflow.keras.optimizers import Adam
from keras.losses import CategoricalCrossentropy
from keras.metrics import CategoricalAccuracy, Precision, Recall
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from keras.applications import MobileNetV2
from tensorflow.keras import regularizers


COMMON_FILENAME = 'mn_'+ augmentation_type+'_aug_'+ samplesize

WEIGHTS_DIR = '/content/drive/MyDrive/progetto-daml/weights'
HISTORY_DIR = '/content/drive/MyDrive/progetto-daml/train-hist'
os.makedirs(WEIGHTS_DIR, exist_ok=True)
os.makedirs(HISTORY_DIR, exist_ok=True)
CHECKPOINT_FILE = f'{WEIGHTS_DIR}/{COMMON_FILENAME}.h5'
HISTORY_FILE = f'{HISTORY_DIR}/history_{COMMON_FILENAME}'


def build_mobilenetv2(input_shape, num_classes, l2_coef=1e-3):
    base_model = MobileNetV2(
        input_shape=input_shape,
        include_top=False,
        weights='imagenet'
    )
    base_model.trainable = False   # freeze weights

    # Full model
    inputs = Input(shape=input_shape)
    x = base_model(inputs, training=False)

    x = Flatten()(x)
    x = Dropout(0.4)(x)

    outputs = Dense(
        num_classes,
        activation='softmax',
        kernel_regularizer=regularizers.l2(l2_coef)
    )(x)

    return Model(inputs,outputs)

from tensorflow.keras import backend as K

class CategoricalFocalCrossentropy(tf.keras.losses.Loss):
    def __init__(self, alpha=0.25, gamma=2.0, from_logits=False, name="categorical_focal_crossentropy"):
        super().__init__(name=name)
        self.alpha = alpha
        self.gamma = gamma
        self.from_logits = from_logits

    def call(self, y_true, y_pred):
        if self.from_logits:
            y_pred = tf.nn.softmax(y_pred)
        y_true = tf.cast(y_true, tf.float32)

        # Clip predictions to prevent log(0)
        y_pred = tf.clip_by_value(y_pred, K.epsilon(), 1 - K.epsilon())

        # Compute cross-entropy
        cross_entropy = -y_true * tf.math.log(y_pred)

        # Compute focal weight
        weights = self.alpha * tf.math.pow((1 - y_pred), self.gamma)

        # Apply focal weight
        loss = weights * cross_entropy

        # Reduce across classes
        return tf.reduce_sum(loss, axis=1)

# %%
    EARLY_STOP_PATIENCE = 3
    num_classes = len(class_names)
    model = build_mobilenetv2(input_shape=(IMG_SIZE[0], IMG_SIZE[1], 3), num_classes=num_classes)

    optimizer = Adam(learning_rate=0.001)
    model.compile(
        optimizer=optimizer,
        loss=CategoricalFocalCrossentropy(alpha = 0.25, gamma = 2),
        metrics=['accuracy']
    )

    model.build(input_shape=(None, IMG_SIZE[0], IMG_SIZE[1], 3))  # Build the model with dynamic batch size
    model.summary()
# Out:
# Model: "functional_9"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_18 (InputLayer)     │ (None, 128, 128, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ mobilenetv2_1.00_128            │ (None, 4, 4, 1280)     │     2,257,984 │
# │ (Functional)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_8 (Flatten)             │ (None, 20480)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_10 (Dropout)            │ (None, 20480)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_9 (Dense)                 │ (None, 38)             │       778,278 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,036,262 (11.58 MB)
#  Trainable params: 778,278 (2.97 MB)
#  Non-trainable params: 2,257,984 (8.61 MB)

# %%
# Model Training
from tensorflow.keras.optimizers import Adam
optimizer = Adam(learning_rate=STARTING_LR)
model.compile(
    optimizer=optimizer,
    loss=CategoricalCrossentropy(),
    metrics=['accuracy']
)

n_epochs = N_EPOCHS

history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=N_EPOCHS,
    callbacks=[
        EarlyStopping(monitor='val_accuracy',
                      patience=EARLY_STOP_PATIENCE,
                      restore_best_weights=True,
                      verbose=1),
        ModelCheckpoint(CHECKPOINT_FILE,
                        monitor='val_accuracy', save_best_only=True,
                        verbose=1),
        ReduceLROnPlateau(monitor='val_accuracy',
                          factor=0.2, patience=REDUCE_LR_PATIENCE,
                          verbose=1,)
    ]
)
# Out:
# Epoch 1/50
# 1358/1358 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.4745 - loss: 1.9466
# Epoch 1: val_accuracy improved from -inf to 0.45701, saving model to /content/drive/MyDrive/progetto-daml/weights/color_aug_1143.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 1358/1358 ━━━━━━━━━━━━━━━━━━━━ 84s 56ms/step - accuracy: 0.4746 - loss: 1.9462 - val_accuracy: 0.4570 - val_loss: 3.1834 - learning_rate: 2.0000e-04
# Epoch 2/50
# 1357/1358 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.7953 - loss: 0.6969
# Epoch 2: val_accuracy improved from 0.45701 to 0.46456, saving model to /content/drive/MyDrive/progetto-daml/weights/color_aug_1143.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 1358/1358 ━━━━━━━━━━━━━━━━━━━━ 69s 51ms/step - accuracy: 0.7953 - loss: 0.6968 - val_accuracy: 0.4646 - val_loss: 3.8041 - learning_rate: 2.0000e-04
# Epoch 3/50
# 1357/1358 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.8627 - loss: 0.4640
# Epoch 3: val_accuracy improved from 0.46456 to 0.48739, saving model to /content/drive/MyDrive/progetto-daml/weights/color_aug_1143.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 1358/1358 ━━━━━━━━━━━━━━━━━━━━ 69s 51ms/step - accuracy: 0.8627 - loss: 0.4640 - val_accuracy: 0.4874 - val_loss: 4.2129 - learning_rate: 2.0000e-04
# Epoch 4/50
# 1356/1358 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.8982 - loss: 0.3425
# Epoch 4: val_accuracy did not improve from 0.48739
# 1358/1358 ━━━━━━━━━━━━━━━━━━━━ 69s 51ms/step - accuracy: 0.8982 - loss: 0.3424 - val_accuracy: 0.4747 - val_loss: 4.6613 - learning_rate: 2.0000e-04
# Epoch 5/50
# 1356/1358 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.9232 - loss: 0.2588
# Epoch 5: val_accuracy did not improve from 0.48739
# 1358/1358 ━━━━━━━━━━━━━━━━━━━━ 69s 51ms/step - accuracy: 0.9232 - loss: 0.2587 - val_accuracy: 0.4704 - val_loss: 5.3166 - learning_rate: 2.0000e-04
# Epoch 6/50
# 1357/1358 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.9424 - loss: 0.1981
# Epoch 6: val_accuracy improved from 0.48739 to 0.50249, saving model to /content/drive/MyDrive/progetto-daml/weights/color_aug_1143.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 1358/1358 ━━━━━━━━━━━━━━━━━━━━ 69s 51ms/step - accuracy: 0.9425 - loss: 0.1981 - val_accuracy: 0.5025 - val_loss: 5.4820 - learning_rate: 2.0000e-04
# Epoch 7/50
# 1358/1358 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.9548 - loss: 0.1526
# Epoch 7: val_accuracy did not improve from 0.50249
# 1358/1358 ━━━━━━━━━━━━━━━━━━━━ 69s 51ms/step - accuracy: 0.9548 - loss: 0.1526 - val_accuracy: 0.4929 - val_loss: 5.7464 - learning_rate: 2.0000e-04
# Epoch 8/50
# 1356/1358 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.9655 - loss: 0.1227
# Epoch 8: val_accuracy did not improve from 0.50249
# 1358/1358 ━━━━━━━━━━━━━━━━━━━━ 69s 50ms/step - accuracy: 0.9655 - loss: 0.1226 - val_accuracy: 0.4852 - val_loss: 6.4162 - learning_rate: 2.0000e-04
# Epoch 9/50
# 1356/1358 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.9732 - loss: 0.0966
# Epoch 9: val_accuracy did not improve from 0.50249
#
# Epoch 9: ReduceLROnPlateau reducing learning rate to 3.9999998989515007e-05.
# 1358/1358 ━━━━━━━━━━━━━━━━━━━━ 69s 51ms/step - accuracy: 0.9732 - loss: 0.0966 - val_accuracy: 0.4712 - val_loss: 6.7552 - learning_rate: 2.0000e-04
# Epoch 10/50
# 1358/1358 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.9896 - loss: 0.0471
# Epoch 10: val_accuracy improved from 0.50249 to 0.50525, saving model to /content/drive/MyDrive/progetto-daml/weights/color_aug_1143.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 1358/1358 ━━━━━━━━━━━━━━━━━━━━ 69s 51ms/step - accuracy: 0.9896 - loss: 0.0471 - val_accuracy: 0.5052 - val_loss: 6.8930 - learning_rate: 4.0000e-05
# Epoch 11/50
# 1357/1358 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.9947 - loss: 0.0347
# Epoch 11: val_accuracy did not improve from 0.50525
# 1358/1358 ━━━━━━━━━━━━━━━━━━━━ 69s 51ms/step - accuracy: 0.9947 - loss: 0.0347 - val_accuracy: 0.4983 - val_loss: 7.1367 - learning_rate: 4.0000e-05
# Epoch 12/50
# 1356/1358 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.9955 - loss: 0.0298
# Epoch 12: val_accuracy did not improve from 0.50525
# 1358/1358 ━━━━━━━━━━━━━━━━━━━━ 69s 51ms/step - accuracy: 0.9955 - loss: 0.0298 - val_accuracy: 0.5027 - val_loss: 7.3566 - learning_rate: 4.0000e-05
# Epoch 13/50
# 1356/1358 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.9966 - loss: 0.0255
# Epoch 13: val_accuracy improved from 0.50525 to 0.50911, saving model to /content/drive/MyDrive/progetto-daml/weights/color_aug_1143.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 1358/1358 ━━━━━━━━━━━━━━━━━━━━ 69s 51ms/step - accuracy: 0.9966 - loss: 0.0255 - val_accuracy: 0.5091 - val_loss: 7.5668 - learning_rate: 4.0000e-05
# Epoch 14/50
# 1357/1358 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.9983 - loss: 0.0215
# Epoch 14: val_accuracy did not improve from 0.50911
# 1358/1358 ━━━━━━━━━━━━━━━━━━━━ 69s 51ms/step - accuracy: 0.9983 - loss: 0.0215 - val_accuracy: 0.5071 - val_loss: 7.7350 - learning_rate: 4.0000e-05
# Epoch 15/50
# 1357/1358 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.9985 - loss: 0.0191
# Epoch 15: val_accuracy did not improve from 0.50911
# 1358/1358 ━━━━━━━━━━━━━━━━━━━━ 69s 51ms/step - accuracy: 0.9985 - loss: 0.0191 - val_accuracy: 0.5067 - val_loss: 7.9128 - learning_rate: 4.0000e-05
# Epoch 16/50
# 1357/1358 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.9985 - loss: 0.0164
# Epoch 16: val_accuracy did not improve from 0.50911
#
# Epoch 16: ReduceLROnPlateau reducing learning rate to 7.999999797903002e-06.
# 1358/1358 ━━━━━━━━━━━━━━━━━━━━ 69s 51ms/step - accuracy: 0.9985 - loss: 0.0164 - val_accuracy: 0.5062 - val_loss: 8.1530 - learning_rate: 4.0000e-05
# Epoch 17/50
# 1357/1358 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.9993 - loss: 0.0132
# Epoch 17: val_accuracy did not improve from 0.50911
# 1358/1358 ━━━━━━━━━━━━━━━━━━━━ 69s 51ms/step - accuracy: 0.9993 - loss: 0.0132 - val_accuracy: 0.5082 - val_loss: 8.1138 - learning_rate: 8.0000e-06
# Epoch 17: early stopping
# Restoring model weights from the end of the best epoch: 13.

# %%
model.save('/content/drive/MyDrive/progetto-daml/model_mn_'+ augmentation_type+'_aug_'+ samplesize+'.keras')

# %%
import pickle
with open(HISTORY_FILE+'_mn_.pkl', 'wb') as f:
    pickle.dump(history.history, f)

# %%
# !mkdir -p src
# !cp /content/drive/MyDrive/progetto-daml/src/preprocessing.py src/
# !cp /content/drive/MyDrive/progetto-daml/src/plotting.py src/plotting.py

# %%
import sys
sys.path.append('/content/src')

# %%
# Plotting the train. history
from plotting import plot_model_history_m

plot_model_history_m(history)
plt.savefig(HISTORY_FILE+'_m.png', dpi=400, bbox_inches='tight')
